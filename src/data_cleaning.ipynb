# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/python_faq_dataset.csv')
print(df.head())
# Out:
#                                             question  \
# 0  !cat datasets/Admission_Predict.csv\r\nERROR:\...
# 1  "All O(1) functions take exactly the same amou...
# 2  "Could not find the version that satisfies the...
# 3  "Error: Tesseract (legacy) engine requested, b...
# 4  "No Python interpreter is selected. You need t...
#
#                                               answer           source  \
# 0           Try !more datasets/Admission_Predict.csv  filtered_basics
# 1  False. O(1) means constant time. This means th...  filtered_basics
# 2  Please correct your spelling of pip install vi...  filtered_basics
# 3  Message is clear: you asked tesseract to use l...  filtered_basics
# 4  Use ctrl+shift+P and then search for "Python: ...  filtered_basics
#
#       score               tags         topic  q_length  a_length  \
# 0  0.000000      python,pandas  data_science       134        40
# 1  1.200000             python  control_flow       118      1234
# 2 -0.099668  python,virtualenv       modules       513       111
# 3  0.197375   python,tesseract  control_flow       373       176
# 4  0.000000             python  control_flow       141        66
#
#    quality_score    difficulty
# 0              2      advanced
# 1              6      beginner
# 2              3  intermediate
# 3              4      beginner
# 4              3      beginner

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (21677, 10)
#
# Columns:
# ['question', 'answer', 'source', 'score', 'tags', 'topic', 'q_length', 'a_length', 'quality_score', 'difficulty']

# %%
print("=== BEFORE CLEANING ===")
print("Total rows:", len(df))
print("\nMissing values:")
print(df.isnull().sum())
print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# === BEFORE CLEANING ===
# Total rows: 21677
#
# Missing values:
# question            0
# answer              0
# source              0
# score            1000
# tags             1000
# topic               0
# q_length            0
# a_length            0
# quality_score       0
# difficulty          0
# dtype: int64
#
# Duplicate rows: 0

# %%
# Fill missing values
df['score'] = df['score'].fillna(0)
df['tags'] = df['tags'].fillna('unknown')

print("=== AFTER CLEANING ===")
print(df.isnull().sum())
# Out:
# === AFTER CLEANING ===
# question         0
# answer           0
# source           0
# score            0
# tags             0
# topic            0
# q_length         0
# a_length         0
# quality_score    0
# difficulty       0
# dtype: int64

# %%
df.to_csv('../data/cleaned_python_faq.csv', index=False)
print("Saved successfully!")
# Out:
# Saved successfully!

# %%
from pypdf import PdfReader

# %%
reader = PdfReader("../data/thinkpython2.pdf")
print("Pages:", len(reader.pages))
# Out:
# Pages: 244

# %%
text = ""

for page in reader.pages:
    page_text = page.extract_text()
    if page_text:
        text += page_text + "\n"

print("Extraction complete")
# Out:
# Extraction complete

# %%
print(text[:3000])
# Out:
# Think Python
# How to Think Like a Computer Scientist
# 2nd Edition, Version 2.4.0
# Think Python
# How to Think Like a Computer Scientist
# 2nd Edition, Version 2.4.0
# Allen Downey
# Green Tea Press
# Needham, Massachusetts
# Copyright © 2015 Allen Downey.
# Green Tea Press
# 9 Washburn Ave
# Needham MA 02492
# Permission is granted to copy, distribute, and/or modify this document under the terms of the
# Creative Commons Attribution-NonCommercial 3.0 Unported License, which is available at http:
# //creativecommons.org/licenses/by-nc/3.0/.
# The original form of this book is LATEX source code. Compiling this LATEX source has the effect of gen-
# erating a device-independent representation of a textbook, which can be converted to other formats
# and printed.
# The LATEX source for this book is available from http://www.thinkpython.com
# Preface
# The strange history of this book
# In January 1999 I was preparing to teach an introductory programming class in Java. I had
# taught it three times and I was getting frustrated. The failure rate in the class was too high
# and, even for students who succeeded, the overall level of achievement was too low.
# One of the problems I saw was the books. They were too big, with too much unnecessary
# detail about Java, and not enough high-level guidance about how to program. And they all
# suffered from the trap door effect: they would start out easy, proceed gradually, and then
# somewhere around Chapter 5 the bottom would fall out. The students would get too much
# new material, too fast, and I would spend the rest of the semester picking up the pieces.
# Two weeks before the ﬁrst day of classes, I decided to write my own book. My goals were:
# • Keep it short. It is better for students to read 10 pages than not read 50 pages.
# • Be careful with vocabulary. I tried to minimize jargon and deﬁne each term at ﬁrst
# use.
# • Build gradually. To avoid trap doors, I took the most difﬁcult topics and split them
# into a series of small steps.
# • Focus on programming, not the programming language. I included the minimum
# useful subset of Java and left out the rest.
# I needed a title, so on a whim I chose How to Think Like a Computer Scientist.
# My ﬁrst version was rough, but it worked. Students did the reading, and they understood
# enough that I could spend class time on the hard topics, the interesting topics and (most
# important) letting the students practice.
# I released the book under the GNU Free Documentation License, which allows users to
# copy, modify, and distribute the book.
# What happened next is the cool part. Jeff Elkner, a high school teacher in Virginia, adopted
# my book and translated it into Python. He sent me a copy of his translation, and I had the
# unusual experience of learning Python by reading my own book. As Green Tea Press, I
# published the ﬁrst Python version in 2001.
# In 2003 I started teaching at Olin College and I got to teach Python for the ﬁrst time. The
# contrast with Java was striking. Students struggled less, learned more, worked on more
# interesting projects, a

# %%
cleaned_text = text.replace("\n", " ")
cleaned_text = " ".join(cleaned_text.split())

print(cleaned_text[:1000])
# Out:
# Think Python How to Think Like a Computer Scientist 2nd Edition, Version 2.4.0 Think Python How to Think Like a Computer Scientist 2nd Edition, Version 2.4.0 Allen Downey Green Tea Press Needham, Massachusetts Copyright © 2015 Allen Downey. Green Tea Press 9 Washburn Ave Needham MA 02492 Permission is granted to copy, distribute, and/or modify this document under the terms of the Creative Commons Attribution-NonCommercial 3.0 Unported License, which is available at http: //creativecommons.org/licenses/by-nc/3.0/. The original form of this book is LATEX source code. Compiling this LATEX source has the effect of gen- erating a device-independent representation of a textbook, which can be converted to other formats and printed. The LATEX source for this book is available from http://www.thinkpython.com Preface The strange history of this book In January 1999 I was preparing to teach an introductory programming class in Java. I had taught it three times and I was getting frustrated. The fa

# %%
with open("../data/cleaned_thinkpython2.txt", "w", encoding="utf-8") as f:
    f.write(cleaned_text)

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
import pandas as pd
import json

# %%
essay_df = pd.read_csv('../data/essay_assistance_raw.csv')
essay_df.head()
# Out:
#       id                      essay_topic                subject  grade_level  \
# 0  ES001  Impact of social media on youth                English           11
# 1  ES002   Climate change and its effects  Environmental Science           12
# 2  ES003  Role of technology in education                English           10
# 3  ES004       Importance of biodiversity                Biology           11
# 4  ES005       Should homework be banned?                English            9
#
#       agent_type  word_count  grammar_score  structure_score  \
# 0  Essay Writing       520.0             88               90
# 1  Essay Writing       610.0             92               88
# 2  Essay Writing         NaN             75               70
# 3  Essay Writing       480.0             85               82
# 4  Essay Writing       350.0            110               78
#
#    originality_score  overall_score feedback_given            timestamp
# 0                 85             87            Yes  2024-01-10 13:00:00
# 1                 90             90            Yes  2024-01-11 14:00:00
# 2                 80             75             No  2024-01-11 15:00:00
# 3                 88             85            Yes  2024-01-12 10:00:00
# 4                 80             78            Yes  2024-01-13 11:00:00

# %%
print("Shape:", essay_df.shape)
print(essay_df.columns.tolist())
print(essay_df.isnull().sum())
print("Duplicates:", essay_df.duplicated().sum())
# Out:
# Shape: (8, 12)
# ['id', 'essay_topic', 'subject', 'grade_level', 'agent_type', 'word_count', 'grammar_score', 'structure_score', 'originality_score', 'overall_score', 'feedback_given', 'timestamp']
# id                   0
# essay_topic          1
# subject              0
# grade_level          0
# agent_type           0
# word_count           1
# grammar_score        0
# structure_score      0
# originality_score    0
# overall_score        0
# feedback_given       0
# timestamp            0
# dtype: int64
# Duplicates: 0

# %%
essay_df = essay_df.drop_duplicates()
essay_df = essay_df.fillna("unknown")

# %%
essay_df.to_csv('../data/cleaned/cleaned_essay_assistance.csv', index=False)

# %%
qa_df = pd.read_csv('../data/qa_interactions_raw.csv')
qa_df.head()
# Out:
#       id                           student_query      subject  grade_level  \
# 0  QA001            What is Newton's second law?      Physics           10
# 1  QA002        Explain photosynthesis in detail      Biology            9
# 2  QA003     How do I solve quadratic equations?  Mathematics           11
# 3  QA004                What caused World War I?      History           10
# 4  QA005  Difference between mitosis and meiosis      Biology           12
#
#   agent_type  response_time_sec  student_rating resolved            timestamp  \
# 0        Q&A                3.2             4.0      Yes  2024-01-10 09:15:00
# 1        Q&A                5.1             5.0      Yes  2024-01-10 10:02:00
# 2        Q&A                4.8             3.0      Yes  2024-01-10 11:30:00
# 3        Q&A                NaN             NaN       No  2024-01-11 08:45:00
# 4        Q&A                6.0             5.0      Yes  2024-01-11 09:00:00
#
#   session_id
# 0       S001
# 1       S002
# 2       S003
# 3       S004
# 4       S005

# %%
print(qa_df.shape)
print(qa_df.isnull().sum())
print(qa_df.duplicated().sum())
# Out:
# (12, 10)
# id                   0
# student_query        1
# subject              0
# grade_level          0
# agent_type           0
# response_time_sec    1
# student_rating       1
# resolved             0
# timestamp            0
# session_id           0
# dtype: int64
# 0

# %%
qa_df = qa_df.drop_duplicates()
qa_df = qa_df.fillna("unknown")
qa_df.to_csv('../data/cleaned/cleaned_qa_interactions.csv', index=False)

# %%
study_df = pd.read_csv('../data/study_schedules_raw.csv')
study_df.head()
# Out:
#       id student_id      subject planned_date  study_duration_min completed  \
# 0  SP001     STU101  Mathematics   2024-01-15                  60       Yes
# 1  SP002     STU102      Physics   2024-01-15                  45       Yes
# 2  SP003     STU103    Chemistry   2024-01-16                 -30        No
# 3  SP004     STU101      Biology   2024-01-16                  90       Yes
# 4  SP005     STU104      English   2024-01-17                  30       yes
#
#   agent_suggestion difficulty_level  performance_after            timestamp
# 0              Yes             Hard               78.0  2024-01-15 18:00:00
# 1              Yes           Medium               82.0  2024-01-15 19:00:00
# 2              Yes             Easy                NaN  2024-01-16 09:00:00
# 3               No           Medium               88.0  2024-01-16 20:00:00
# 4              Yes             easy               75.0  2024-01-17 08:00:00

# %%
print(study_df.shape)
print(study_df.isnull().sum())

study_df = study_df.drop_duplicates()
study_df = study_df.fillna("unknown")

study_df.to_csv('../data/cleaned/cleaned_study_schedules.csv', index=False)
# Out:
# (10, 10)
# id                    0
# student_id            1
# subject               0
# planned_date          0
# study_duration_min    0
# completed             0
# agent_suggestion      0
# difficulty_level      0
# performance_after     2
# timestamp             0
# dtype: int64

# %%
excel_df = pd.read_excel('../data/academic_ai_raw_data.xlsx')
excel_df.head()
# Out:
#       ID                           Student Query      Subject  Grade Level  \
# 0  QA001            What is Newton's second law?      Physics           10
# 1  QA002        Explain photosynthesis in detail      Biology            9
# 2  QA003     How do I solve quadratic equations?  Mathematics           11
# 3  QA004                What caused World War I?      History           10
# 4  QA005  Difference between mitosis and meiosis      Biology           12
#
#   Agent Type  Response Time Sec  Student Rating Resolved            Timestamp  \
# 0        Q&A                3.2             4.0      Yes  2024-01-10 09:15:00
# 1        Q&A                5.1             5.0      Yes  2024-01-10 10:02:00
# 2        Q&A                4.8             3.0      Yes  2024-01-10 11:30:00
# 3        Q&A                NaN             NaN       No  2024-01-11 08:45:00
# 4        Q&A                6.0             5.0      Yes  2024-01-11 09:00:00
#
#   Session ID
# 0       S001
# 1       S002
# 2       S003
# 3       S004
# 4       S005

# %%
print(excel_df.shape)
print(excel_df.isnull().sum())
# Out:
# (12, 10)
# ID                   0
# Student Query        1
# Subject              0
# Grade Level          0
# Agent Type           0
# Response Time Sec    1
# Student Rating       1
# Resolved             0
# Timestamp            0
# Session ID           0
# dtype: int64

# %%
excel_df = excel_df.drop_duplicates()
excel_df = excel_df.fillna("unknown")

excel_df.to_csv('../data/cleaned/cleaned_academic_ai_excel.csv', index=False)

# %%
with open('../data/academic_ai_raw_data.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

print(type(data))
# Out:
# <class 'dict'>

# %%
print(data.keys())
# Out:
# dict_keys(['project', 'collection_date', 'source', 'datasets', 'known_issues'])

# %%
for key in data:
    print(key, type(data[key]))
# Out:
# project <class 'str'>
# collection_date <class 'str'>
# source <class 'str'>
# datasets <class 'dict'>
# known_issues <class 'list'>

# %%
print(data["datasets"].keys())
# Out:
# dict_keys(['qa_interactions', 'essay_assistance', 'study_schedules'])

# %%
for key in data["datasets"]:
    print(key, type(data["datasets"][key]))
# Out:
# qa_interactions <class 'list'>
# essay_assistance <class 'list'>
# study_schedules <class 'list'>

# %%
import pandas as pd

qa_json_df = pd.DataFrame(data["datasets"]["qa_interactions"])
essay_json_df = pd.DataFrame(data["datasets"]["essay_assistance"])
study_json_df = pd.DataFrame(data["datasets"]["study_schedules"])

# %%
qa_json_df.head()
# Out:
#       id                           student_query      subject grade_level  \
# 0  QA001            What is Newton's second law?      Physics          10
# 1  QA002        Explain photosynthesis in detail      Biology           9
# 2  QA003     How do I solve quadratic equations?  Mathematics          11
# 3  QA004                What caused World War I?      History          10
# 4  QA005  Difference between mitosis and meiosis      Biology          12
#
#   agent_type  response_time_sec  student_rating resolved            timestamp  \
# 0        Q&A                3.2             4.0      Yes  2024-01-10 09:15:00
# 1        Q&A                5.1             5.0      Yes  2024-01-10 10:02:00
# 2        Q&A                4.8             3.0      Yes  2024-01-10 11:30:00
# 3        Q&A                NaN             NaN       No  2024-01-11 08:45:00
# 4        Q&A                6.0             5.0      Yes  2024-01-11 09:00:00
#
#   session_id
# 0       S001
# 1       S002
# 2       S003
# 3       S004
# 4       S005

# %%
essay_json_df.head()
# Out:
#       id                      essay_topic                subject grade_level  \
# 0  ES001  Impact of social media on youth                English          11
# 1  ES002   Climate change and its effects  Environmental Science          12
# 2  ES003  Role of technology in education                English          10
# 3  ES004       Importance of biodiversity                Biology          11
# 4  ES005       Should homework be banned?                English           9
#
#       agent_type  word_count  grammar_score  structure_score  \
# 0  Essay Writing       520.0             88               90
# 1  Essay Writing       610.0             92               88
# 2  Essay Writing         NaN             75               70
# 3  Essay Writing       480.0             85               82
# 4  Essay Writing       350.0            110               78
#
#    originality_score  overall_score feedback_given            timestamp
# 0                 85             87            Yes  2024-01-10 13:00:00
# 1                 90             90            Yes  2024-01-11 14:00:00
# 2                 80             75             No  2024-01-11 15:00:00
# 3                 88             85            Yes  2024-01-12 10:00:00
# 4                 80             78            Yes  2024-01-13 11:00:00

# %%
study_json_df.head()
# Out:
#       id student_id      subject planned_date  study_duration_min completed  \
# 0  SP001     STU101  Mathematics   2024-01-15                  60       Yes
# 1  SP002     STU102      Physics   2024-01-15                  45       Yes
# 2  SP003     STU103    Chemistry   2024-01-16                 -30        No
# 3  SP004     STU101      Biology   2024-01-16                  90       Yes
# 4  SP005     STU104      English   2024-01-17                  30       yes
#
#   agent_suggestion difficulty_level  performance_after            timestamp
# 0              Yes             Hard               78.0  2024-01-15 18:00:00
# 1              Yes           Medium               82.0  2024-01-15 19:00:00
# 2              Yes             Easy                NaN  2024-01-16 09:00:00
# 3               No           Medium               88.0  2024-01-16 20:00:00
# 4              Yes             easy               75.0  2024-01-17 08:00:00

# %%
print("QA shape:", qa_json_df.shape)
print("Essay shape:", essay_json_df.shape)
print("Study shape:", study_json_df.shape)
# Out:
# QA shape: (12, 10)
# Essay shape: (8, 12)
# Study shape: (10, 10)

# %%
print(qa_json_df.isnull().sum())
print(essay_json_df.isnull().sum())
print(study_json_df.isnull().sum())
# Out:
# id                   0
# student_query        0
# subject              0
# grade_level          0
# agent_type           0
# response_time_sec    1
# student_rating       1
# resolved             0
# timestamp            0
# session_id           0
# dtype: int64
# id                   0
# essay_topic          0
# subject              0
# grade_level          0
# agent_type           0
# word_count           1
# grammar_score        0
# structure_score      0
# originality_score    0
# overall_score        0
# feedback_given       0
# timestamp            0
# dtype: int64
# id                    0
# student_id            1
# subject               0
# planned_date          0
# study_duration_min    0
# completed             0
# agent_suggestion      0
# difficulty_level      0
# performance_after     2
# timestamp             0
# dtype: int64

# %%
qa_json_df = qa_json_df.drop_duplicates().fillna("unknown")
essay_json_df = essay_json_df.drop_duplicates().fillna("unknown")
study_json_df = study_json_df.drop_duplicates().fillna("unknown")

# %%
qa_json_df.to_csv('../data/cleaned/cleaned_json_qa.csv', index=False)
essay_json_df.to_csv('../data/cleaned/cleaned_json_essay.csv', index=False)
study_json_df.to_csv('../data/cleaned/cleaned_json_study.csv', index=False)

print("Saved all cleaned JSON datasets!")
# Out:
# Saved all cleaned JSON datasets!
